# %%
import pandas as pd

# %%
data = {
    'Français': ["Bonjour", "Salut", "Comment tu t'appelles ?", "Je m'appelle", "Comment ça va ?", "Ça va bien", "Ça va mal", "Je suis désolé", "Merci", "De rien", "S'il vous plaît", "Oui", "Non", "Excusez-moi", "Au revoir"],
    'Spanish': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None],
    'English': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None],
    'Italian': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
}

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#                    Français Spanish English Italian
# 0                   Bonjour    None    None    None
# 1                     Salut    None    None    None
# 2   Comment tu t'appelles ?    None    None    None
# 3              Je m'appelle    None    None    None
# 4           Comment ça va ?    None    None    None
# 5                Ça va bien    None    None    None
# 6                 Ça va mal    None    None    None
# 7            Je suis désolé    None    None    None
# 8                     Merci    None    None    None
# 9                   De rien    None    None    None
# 10          S'il vous plaît    None    None    None
# 11                      Oui    None    None    None
# 12                      Non    None    None    None
# 13              Excusez-moi    None    None    None
# 14                Au revoir    None    None    None

# %%
import google.generativeai as genai

# Fonction de traduction utilisant l'API Generative AI
def translator(prompt):
    # Clé API pour l'accès à Generative AI
    API_KEY = "AIzaSyBgTjTe8wGsvUzgCazb3SeMwyx-zaQyhi0"

    # Configurer l'API Generative AI
    genai.configure(api_key=API_KEY)

    # Préparer le prompt pour la traduction
    translation_prompt = f"Translate this text to English: '{prompt}'. Ne retourne que le texte traduit."

    # Utiliser le modèle Generative AI pour générer la traduction
    try:
        model = genai.GenerativeModel("gemini-1.5-flash")
        response = model.generate_content(translation_prompt)
        return response.text
    except Exception as e:
        return f"An error occurred: {str(e)}"

# %%
translator("Bonjour, comment ça va ?")
# Out:
# 'Hello, how are you? \n'

# %%
dataframe['Anglais'] = dataframe['Français'].apply(translator)

# %%
dataframe
# Out:
#                    Français Spanish English Italian  \
# 0                   Bonjour    None    None    None
# 1                     Salut    None    None    None
# 2   Comment tu t'appelles ?    None    None    None
# 3              Je m'appelle    None    None    None
# 4           Comment ça va ?    None    None    None
# 5                Ça va bien    None    None    None
# 6                 Ça va mal    None    None    None
# 7            Je suis désolé    None    None    None
# 8                     Merci    None    None    None
# 9                   De rien    None    None    None
# 10          S'il vous plaît    None    None    None
# 11                      Oui    None    None    None
# 12                      Non    None    None    None
# 13              Excusez-moi    None    None    None
# 14                Au revoir    None    None    None
#
#                                               Anglais
# 0   An error occurred: 429 Resource has been exhau...
# ...

# %%
dataframe.to_csv('all_translations.csv', index=False, sep=';')
